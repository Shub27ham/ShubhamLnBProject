# %%
import pandas as pd

# %%
data = {'apple': [1,2,0,5],'orange':[2,0,1,0.5], 'banana': [0,3,1,0]}

# %%
data
# Out:
# {'apple': [1, 2, 0, 5], 'orange': [2, 0, 1, 0.5], 'banana': [0, 3, 1, 0]}

# %%
df1 =pd.DataFrame(data, index = ['A','B','C','D'])

# %%
df1
# Out:
#    apple  orange  banana
# A      1     2.0       0
# B      2     0.0       3
# C      0     1.0       1
# D      5     0.5       0

# %%
df = pd.read_csv('advertising.csv')
df
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3   12.0
# 3    151.5   41.3       58.5   16.5
# 4    180.8   10.8       58.4   17.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4
#
# [200 rows x 4 columns]

# %%
df.head(15)
# Out:
#        TV  Radio  Newspaper  Sales
# 0   230.1   37.8       69.2   22.1
# 1    44.5   39.3       45.1   10.4
# 2    17.2   45.9       69.3   12.0
# 3   151.5   41.3       58.5   16.5
# 4   180.8   10.8       58.4   17.9
# 5     8.7   48.9       75.0    7.2
# 6    57.5   32.8       23.5   11.8
# 7   120.2   19.6       11.6   13.2
# 8     8.6    2.1        1.0    4.8
# 9   199.8    2.6       21.2   15.6
# 10   66.1    5.8       24.2   12.6
# 11  214.7   24.0        4.0   17.4
# 12   23.8   35.1       65.9    9.2
# 13   97.5    7.6        7.2   13.7
# 14  204.1   32.9       46.0   19.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   Radio      200 non-null    float64
#  2   Newspaper  200 non-null    float64
#  3   Sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %%
df.isnull()
# Out:
#         TV  Radio  Newspaper  Sales
# 0    False  False      False  False
# 1    False  False      False  False
# 2    False  False      False  False
# 3    False  False      False  False
# 4    False  False      False  False
# ..     ...    ...        ...    ...
# 195  False  False      False  False
# 196  False  False      False  False
# 197  False  False      False  False
# 198  False  False      False  False
# 199  False  False      False  False
#
# [200 rows x 4 columns]

# %%
df.shape
# Out:
# (200, 4)

# %%
df.describe()
# Out:
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   15.130500
# std     85.854236   14.846809   21.778621    5.283892
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   11.000000
# 50%    149.750000   22.900000   25.750000   16.000000
# 75%    218.825000   36.525000   45.100000   19.050000
# max    296.400000   49.600000  114.000000   27.000000

# %%
df.iloc[5]
# Out:
# TV            8.7
# Radio        48.9
# Newspaper    75.0
# Sales         7.2
# Name: 5, dtype: float64

# %%
temp_df = df.append(df)
temp_df
# Out:
# <ipython-input-13-40274d65f161>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   temp_df = df.append(df)
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3   12.0
# 3    151.5   41.3       58.5   16.5
# 4    180.8   10.8       58.4   17.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4
#
# [400 rows x 4 columns]

# %%
temp_df.drop_duplicates()
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3   12.0
# 3    151.5   41.3       58.5   16.5
# 4    180.8   10.8       58.4   17.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4
#
# [200 rows x 4 columns]

# %%
temp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 400 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         400 non-null    float64
#  1   Radio      400 non-null    float64
#  2   Newspaper  400 non-null    float64
#  3   Sales      400 non-null    float64
# dtypes: float64(4)
# memory usage: 15.6 KB

# %%
temp_df.drop_duplicates(keep='last',inplace = True)

# %%
temp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   Radio      200 non-null    float64
#  2   Newspaper  200 non-null    float64
#  3   Sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 7.8 KB

# %%
data = {'A':[3,3,3,3],'B':[8,3,3,3]}
demo = pd.DataFrame(data)
demo
# Out:
#    A  B
# 0  3  8
# 1  3  3
# 2  3  3
# 3  3  3

# %%
demo.drop_duplicates(keep='last')
# Out:
#    A  B
# 0  3  8
# 3  3  3

# %%
demo
# Out:
#    A  B
# 0  3  8
# 1  3  3
# 2  3  3
# 3  3  3

# %%
demo.duplicated()
# Out:
# 0    False
# 1    False
# 2     True
# 3     True
# dtype: bool

# %%
demo2 = demo.pivot_table(index=['B'], aggfunc = 'size')
demo2
# Out:
# B
# 3    3
# 8    1
# dtype: int64

# %%
demo.drop_duplicates(subset = ['B'])
# Out:
#    A  B
# 0  3  8
# 1  3  3

# %%
dup =demo[demo.duplicated()]

# %%
dup =demo[demo.duplicated()].count()

# %%
dup
# Out:
# A    2
# B    2
# dtype: int64

# %%
demo.drop_duplicates(keep=False , inplace=True)

# %%
demo
# Out:
#    A  B
# 0  3  8

# %%
df.columns
# Out:
# Index(['TV', 'Radio', 'Newspaper', 'Sales'], dtype='object')

# %%
df.TV
# Out:
# 0      230.1
# 1       44.5
# 2       17.2
# 3      151.5
# 4      180.8
#        ...
# 195     38.2
# 196     94.2
# 197    177.0
# 198    283.6
# 199    232.1
# Name: TV, Length: 200, dtype: float64

# %%
df.rename(columns={'Radio':'Rd'},inplace =True) #To change name of columns

# %%
df
# Out:
#         TV    Rd  Newspaper  Sales
# 0    230.1  37.8       69.2   22.1
# 1     44.5  39.3       45.1   10.4
# 2     17.2  45.9       69.3   12.0
# 3    151.5  41.3       58.5   16.5
# 4    180.8  10.8       58.4   17.9
# ..     ...   ...        ...    ...
# 195   38.2   3.7       13.8    7.6
# 196   94.2   4.9        8.1   14.0
# 197  177.0   9.3        6.4   14.8
# 198  283.6  42.0       66.2   25.5
# 199  232.1   8.6        8.7   18.4
#
# [200 rows x 4 columns]

# %%
df.columns = [col.upper() for col in df]
df.columns                                                       # for column cleanup we use this
# Out:
# Index(['TV', 'RD', 'NEWSPAPER', 'SALES'], dtype='object')

# %%
df
# Out:
#         TV    RD  NEWSPAPER  SALES
# 0    230.1  37.8       69.2   22.1
# 1     44.5  39.3       45.1   10.4
# 2     17.2  45.9       69.3   12.0
# 3    151.5  41.3       58.5   16.5
# 4    180.8  10.8       58.4   17.9
# ..     ...   ...        ...    ...
# 195   38.2   3.7       13.8    7.6
# 196   94.2   4.9        8.1   14.0
# 197  177.0   9.3        6.4   14.8
# 198  283.6  42.0       66.2   25.5
# 199  232.1   8.6        8.7   18.4
#
# [200 rows x 4 columns]

# %%
new_df = pd.read_csv(r'tomobile_data (2).csv')
new_df
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            3                 ?  alfa-romero       gas        std
# 2            1                 ?  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    object
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num-of-doors       205 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
#  15  num-of-cylinders   205 non-null    object
# ...

# %%
new_df.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration',
#        'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
#        'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type',
#        'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
#        'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#        'highway-mpg', 'price'],
#       dtype='object')

# %%
new_df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 200    False
# 201    False
# 202    False
# 203    False
# 204    False
# Length: 205, dtype: bool

# %%
# Selecting duplicate rows except first
# occurrence based on all columns
duplicate = new_df[new_df.duplicated(['normalized-losses', 'make', 'fuel-type', 'aspiration',
       'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
       'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type',
       'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
       'compression-ratio',])]
 
print("Duplicate Rows :")
 
# Print the resultant Dataframe
duplicate
# Out:
# Duplicate Rows :
#      symboling normalized-losses         make fuel-type aspiration  \
# 1            3                 ?  alfa-romero       gas        std
# 26           1               148        dodge       gas        std
# 56           3               150        mazda       gas        std
# 61           1               129        mazda       gas        std
# 62           0               115        mazda       gas        std
# 116          0               161       peugot    diesel      turbo
# 127          3                 ?      porsche       gas        std
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 1            two  convertible          rwd           front        88.6  ...
# 26          four        sedan          fwd           front        93.7  ...
# 56           two    hatchback          rwd           front        95.3  ...
# 61           two    hatchback          fwd           front        98.8  ...
# ...

# %%
new_df1 = pd.read_csv(r'diabetes.csv')
new_df1
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
new_df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
new_df1.info(show_counts = False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Dtype
# ---  ------                    -----
#  0   Pregnancies               int64
#  1   Glucose                   int64
#  2   BloodPressure             int64
#  3   SkinThickness             int64
#  4   Insulin                   int64
#  5   BMI                       float64
#  6   DiabetesPedigreeFunction  float64
#  7   Age                       int64
#  8   Outcome                   int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
new_df1.info(show_counts = False, memory_usage =False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Dtype
# ---  ------                    -----
#  0   Pregnancies               int64
#  1   Glucose                   int64
#  2   BloodPressure             int64
#  3   SkinThickness             int64
#  4   Insulin                   int64
#  5   BMI                       float64
#  6   DiabetesPedigreeFunction  float64
#  7   Age                       int64
#  8   Outcome                   int64
# dtypes: float64(2), int64(7)

# %%
new_df1.info(show_counts = False, memory_usage =False, verbose = False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Columns: 9 entries, Pregnancies to Outcome
# dtypes: float64(2), int64(7)

# %%
new_df1.describe(percentiles =[0.3,0.5,0.7]).T
# Out:
#                           count        mean         std     min      30%  \
# Pregnancies               768.0    3.845052    3.369578   0.000    1.000
# Glucose                   768.0  120.894531   31.972618   0.000  102.000
# BloodPressure             768.0   69.105469   19.355807   0.000   64.000
# SkinThickness             768.0   20.536458   15.952218   0.000    8.200
# Insulin                   768.0   79.799479  115.244002   0.000    0.000
# BMI                       768.0   31.992578    7.884160   0.000   28.200
# DiabetesPedigreeFunction  768.0    0.471876    0.331329   0.078    0.259
# Age                       768.0   33.240885   11.760232  21.000   25.000
# Outcome                   768.0    0.348958    0.476951   0.000    0.000
#
#                                50%       70%     max
# Pregnancies                 3.0000    5.0000   17.00
# Glucose                   117.0000  134.0000  199.00
# BloodPressure              72.0000   78.0000  122.00
# ...

# %%
#new_df1.describe(include=[int],percentiles =[0.3,0.5,0.7]).T

# %%
new_df1.describe(exclude=[int],percentiles =[0.3,0.5,0.7]).T
# Out:
#                           count       mean       std    min     30%      50%  \
# BMI                       768.0  31.992578  7.884160  0.000  28.200  32.0000
# DiabetesPedigreeFunction  768.0   0.471876  0.331329  0.078   0.259   0.3725
#
#                               70%    max
# BMI                       35.4900  67.10
# DiabetesPedigreeFunction   0.5637   2.42

# %%
new_df1.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
new_df1['Glucose'].describe().T
# Out:
# count    768.000000
# mean     120.894531
# std       31.972618
# min        0.000000
# 25%       99.000000
# 50%      117.000000
# 75%      140.250000
# max      199.000000
# Name: Glucose, dtype: float64

# %%
new_df1.isnull()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin    BMI  \
# 0          False    False          False          False    False  False
# 1          False    False          False          False    False  False
# 2          False    False          False          False    False  False
# 3          False    False          False          False    False  False
# 4          False    False          False          False    False  False
# ..           ...      ...            ...            ...      ...    ...
# 763        False    False          False          False    False  False
# 764        False    False          False          False    False  False
# 765        False    False          False          False    False  False
# 766        False    False          False          False    False  False
# 767        False    False          False          False    False  False
#
#      DiabetesPedigreeFunction    Age  Outcome
# 0                       False  False    False
# ...

# %%
new_df1.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
new_df1.isnull().sum().sum()
# Out:
# 0

# %%
new_df1.dropna(inplace=True)
new_df1
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
new_df1.dropna(axis =1) #delete entire columns
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
mean1 = new_df1.mean()
new_df1.fillna(mean1)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
new_df1.fillna(0)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
new_df1['Glucose'].fillna(1,inplace=True)

# %%
new_df1
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
new_df1.columns = [col.lower() for col in new_df1]

# %%
new_df1
# Out:
#      pregnancies  glucose  bloodpressure  skinthickness  insulin   bmi  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      diabetespedigreefunction  age  outcome
# 0                       0.627   50        1
# ...

# %%
df2 = pd.read_csv(r'project2.csv')
df2
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
df2.isnull().sum() #find the null value
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
df2['Churn'] = df2['Churn'].replace(['No'], '0')
df2['Churn'] = df2['Churn'].replace(['Yes'], '1') #replace the yes no value

# %%
df2
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
df2.corr()
# Out:
# <ipython-input-65-e0c6714eb3b3>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df2.corr()
#                 SeniorCitizen    tenure  MonthlyCharges
# SeniorCitizen        1.000000  0.016567        0.220173
# tenure               0.016567  1.000000        0.247900
# MonthlyCharges       0.220173  0.247900        1.000000

# %%
import matplotlib
